# %%
import binarySearchTree as bst

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
n1 = bst.node(1)
for n in range(1,50):
    locals()['node%d' %n] = bst.node(n)

# %%
T1 = bst.Tree(node3)
for node in [7,10,12,14,15,16,17,19,20,21,23,26,28,30,35,38,41,47]:
    T1.insert(locals()['node%d' %node])

# %%
bst.treeplot(T1)

# %%
T2 = bst.Tree(node20)

for node in [35,14,26,39,7,16,3,10,15,17,21,28,38,41,12,19,23,30,47]:
    T2.insert(locals()['node%d' %node])
    
bst.treeplot(T2)
